# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("BlackFriday.csv")

# %%
del df['Product_Category_2']
del df['Product_Category_3']
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby('Age').size()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
sns.set(rc = {'figure.figsize' : (12 , 6)})
sns.countplot(x = "Age" , hue = 'Gender' , data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (12 , 6)})
sns.countplot(x = "Gender" , hue = "Age" , data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (6,6)})
sns.countplot(x = "Gender" , hue = "Marital_Status" , data = df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 2
#       1 sns.set(rc = {'figure.figsize' : (6,6)})
# ----> 2 sns.countplot(x = "Gender" , hue = "Marital_Status" , data = df)
#
# File E:\Machine learning\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File E:\Machine learning\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
sns.set(rc = {'figure.figsize' : (6,6)})
sns.countplot(x = "Marital_Status" , hue = 'Gender' , data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x = df['City_Category'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x = 'City_Category' , hue = 'Age' , data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category').size().plot(kind = 'pie' , autopct = "%0.1f")
# Out:
# <Axes: >

# %%
sns.countplot(x = 'City_Category' , hue = 'Gender' , data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sum_of_purchase_per_city_category = df.groupby('City_Category')['Purchase'].sum()

# %%
sum_of_purchase_per_city_category.plot(kind = 'pie' , autopct = "%0.1f%%")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('City_Category')['Purchase'].mean().plot(kind = 'pie' , autopct = "%0.1f%%")
# Out:
# <Axes: ylabel='Purchase'>

# %%
# Analysis people in city a are spending more money and buying lesser products i.e. expensive 
#products........whereas people in city b are spending less money and buying more products..
